# %% [markdown]
# # Домашнее задание 5.2

# %% [markdown]
# # ✏️ 🗒️ 📝
#
# Сегодня тебе нужно выполнить задачу от руководительницы отдела контент-маркетинга новой онлайн-школы английского языка. Она хочет составить ТЗ копирайтеру на написание постов, но для этого ей нужно знать, какие типы постов популярны. За завтраком вы с ней обсуждали твое последнее занятие с курса Python, где мы парсили страницы сообществ ВК, и у вас появилась идея – проанализировать самые успешные посты известной онлайн-школы Skyeng  в [сообществе Skyeng в ВК](https://vk.com/skyeng).
#
# Теперь перед тобой стоит задача – выгрузить маркетологам для анализа 50 самых популярных постов за все время существования сообщества. Метрику популярности будем считать как сумму лайков, репостов и комментариев к каждому посту. Если останется время, для дополнительного анализа выгрузи все комментарии к этим постам в отдельный файл.

# %% [markdown]
# ## Задание 1
#
# Получи собственный `access_token` в ВК. Важно пройти этот путь самостоятельно, можешь использовать документацию API ВК или рекомендации из ноутбука занятия.  Токен присылай вместе с файлом ноутбука в файле с именем `my_own_token.py`. Обещаем не делать ничего противозаконного.
#
# *Если тебе некомфортно, можешь не присылать токен нам. Однако получить его все же обязательно – это необходимо для полноценного освоения темы урока, а также для выполнения заданий ниже.*

# %%
# читаем токен из файла my_own_token.py, куда мы сохранили access_token
from my_own_token_VK import my_own_token as token

# %% [markdown]
# ## Задание 2
#
# __Сформируй запрос, который получает 100 записей со стены сообщества__
#
# 1. Найди в документации метод, который отдает все записи со стены сообщества Skyeng: https://vk.com/skyeng
# 2. Создай переменую для URL
# 3. Создай переменную с параметрами
# 4. Создай переменную запроса
# 5. Создай переменную, в которой будут данные ответа в формате словаря

# %%
import requests 
import pandas as pd

# %%
url =  'https://api.vk.com/method/wall.get'

params = {
    'domain': 'skyeng',
    'access_token': token,
    'count': 100,
    'v': '5.131'
           }

req = requests.get(url, params=params)
res = req.json()

print('Кол-во записей:', len(pd.DataFrame(res['response'])))
# Out:
# Кол-во записей: 100

# %%
res
# Out:
# {'response': {'count': 8239,
#   'items': [{'id': 89850,
#     'from_id': -51890028,
#     'owner_id': -51890028,
#     'date': 1662710140,
#     'marked_as_ads': 0,
#     'is_favorite': False,
#     'post_type': 'post',
#     'text': 'to declare / proclaim (a period of) mourning — объявлять траур \nday of mourning — траурный день \nnational mourning — национальный траур \nto be in mourning for someone — быть в трауре по кому-то',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662710140,
#        'id': 457282763,
#        'owner_id': -51890028,
#        'access_key': 'fdeb2008c18b540545',
#        'post_id': 89850,
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-79.userapi.com/impg/jvXrC8kT2p2dh7PnYsv1-7kxuZkJR8k9lJonWQ/t_-kuk_sFvg.jpg?size=60x75&quality=95&sign=2fe522ed42b638b7bb3cfc811c904bd1&c_uniq_tag=2dAwmREd_fNXBCx86G0Gk8citNyb4wclz9VW-NnomxM&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun9-79.userapi.com/impg/jvXrC8kT2p2dh7PnYsv1-7kxuZkJR8k9lJonWQ/t_-kuk_sFvg.jpg?size=510x637&quality=95&sign=f92bdbf8a4ec6208f743a73d38e7d5ce&c_uniq_tag=aPhPPeOxXbprOvlGdHEMiO2kxBiTD7_-Y2YuSzZaZm0&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 1, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 29, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 6, 'user_reposted': 0},
#     'views': {'count': 723},
#     'donut': {'is_donut': False},
#     'short_text_rate': 0.8,
#     'hash': 'Ni-5W4wR0zZlEeHTOrpYEELJLoQ'},
#    {'id': 89807,
#     'from_id': -51890028,
#     'owner_id': -51890028,
#     'date': 1662657213,
#     'marked_as_ads': 0,
#     'is_favorite': False,
#     'post_type': 'post',
#     'text': 'Друзья, хотим поделиться классной новостью: сегодня на экраны выходит «Три тысячи лет желаний» — романтическое фэнтези с Тильдой Суинтон и Идрисом Эльбой от Джорджа Миллера, режиссера «Безумного Макса»! \n \nМы вовсе не случайно взялись вам о нем рассказать: наша команда создала эксклюзивные субтитры для предпремьерного показа фильма (поздравьте лайком). \n \nА сейчас самая главная часть: совместно с кинопрокатной компанией «Вольга» хотим подарить вам 10 билетов в кино — по 2 в одни руки :) \n \nУсловия розыгрыша: \n \n1) Быть подписанным на нашу страницу — [club51890028|Skyeng] . \n2) Оставить любой комментарий под этим постом. \n3) Немного подождать! \n \nИтоги подведем уже 9 сентября :) \nНе стройте планы на эти выходные — возможно, вас ждет поход в кино. \n\nУчаствовать могут жители любых городов, билеты будут электронными.',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662652978,
#        'id': 457282761,
#        'owner_id': -51890028,
#        'access_key': 'afc24393cdcdbea256',
#        'post_id': 89807,
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-85.userapi.com/impg/4TIKo-dXn6s48jhzAwQBkkHjnDx-HjTYMIXnIQ/6JEwz_1baG4.jpg?size=75x75&quality=95&sign=f104574331b3a9730263f06c32730a2f&c_uniq_tag=wid6e2XrDkp8NK3kSR4lX0qA_rmt8ts3QxbIB6wbziI&type=album',
#          'type': 's',
#          'width': 75},
#         {'height': 130,
#          'url': 'https://sun9-85.userapi.com/impg/4TIKo-dXn6s48jhzAwQBkkHjnDx-HjTYMIXnIQ/6JEwz_1baG4.jpg?size=130x130&quality=95&sign=ffc63f8b694c10fdddc5a5c31b34f5c6&c_uniq_tag=dJHV2X9UVqJ_D_Abs4pfSFQpr3qF5JisrECUOIeA0Go&type=album',
#          'type': 'm',
#          'width': 130},
#         {'height': 604,
#          'url': 'https://sun9-85.userapi.com/impg/4TIKo-dXn6s48jhzAwQBkkHjnDx-HjTYMIXnIQ/6JEwz_1baG4.jpg?size=604x604&quality=95&sign=5c760b835a1acc334c3837d947a79b0e&c_uniq_tag=RaJfazYfIj0yQfdQKuavXMCk5A7EMWaYOwomSVKCh9M&type=album',
#          'type': 'x',
#          'width': 604},
#         {'height': 807,
#          'url': 'https://sun9-85.userapi.com/impg/4TIKo-dXn6s48jhzAwQBkkHjnDx-HjTYMIXnIQ/6JEwz_1baG4.jpg?size=807x807&quality=95&sign=ac4eb7c05187df4ad88060bb28eae1c5&c_uniq_tag=oDAN0I6JBGLEfKU25CbmeIm_0nPyuHxOPE3u4oaCDE0&type=album',
#          'type': 'y',
#          'width': 807},
#         {'height': 1080,
#          'url': 'https://sun9-85.userapi.com/impg/4TIKo-dXn6s48jhzAwQBkkHjnDx-HjTYMIXnIQ/6JEwz_1baG4.jpg?size=1080x1080&quality=95&sign=d89a7db0fb1dc0a5a7940432d964a5a3&c_uniq_tag=dhmxZwdZC4nyNZ6Dr0aj0BACGcm7Q_uE_HrGtYUul-s&type=album',
#          'type': 'z',
#          'width': 1080},
#         {'height': 130,
#          'url': 'https://sun9-85.userapi.com/impg/4TIKo-dXn6s48jhzAwQBkkHjnDx-HjTYMIXnIQ/6JEwz_1baG4.jpg?size=130x130&quality=95&sign=ffc63f8b694c10fdddc5a5c31b34f5c6&c_uniq_tag=dJHV2X9UVqJ_D_Abs4pfSFQpr3qF5JisrECUOIeA0Go&type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 200,
#          'url': 'https://sun9-85.userapi.com/impg/4TIKo-dXn6s48jhzAwQBkkHjnDx-HjTYMIXnIQ/6JEwz_1baG4.jpg?size=200x200&quality=95&sign=4130d7bb0019b40724d1473baf2f70c3&c_uniq_tag=M9GIns8Pk2rhEFPCmtPJki1zaDaMHKGewJIRCaKz6lc&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 320,
#          'url': 'https://sun9-85.userapi.com/impg/4TIKo-dXn6s48jhzAwQBkkHjnDx-HjTYMIXnIQ/6JEwz_1baG4.jpg?size=320x320&quality=95&sign=4a704d96a9a1cbf4132b51f53a088eba&c_uniq_tag=UiHY6u1UYyamr6DJoyt-1UqHos9Y67N_OGTJqrkG6NI&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 510,
#          'url': 'https://sun9-85.userapi.com/impg/4TIKo-dXn6s48jhzAwQBkkHjnDx-HjTYMIXnIQ/6JEwz_1baG4.jpg?size=510x510&quality=95&sign=e0f40cc1ceb511a04fefd993e35ff00b&c_uniq_tag=WZoB9qodLoXOqETAdTBHfbT-KiIbnggBFdh9g2iaXQU&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 40, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 25, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 9, 'user_reposted': 0},
#     'views': {'count': 5658},
#     'donut': {'is_donut': False},
#     'short_text_rate': 0.8,
#     'hash': 'bLnro8MFqJJ-7oDIdQQV7MPRb0Q'},
#    {'id': 89805,
#     'from_id': -51890028,
#     'owner_id': -51890028,
#     'date': 1662642113,
#     'marked_as_ads': 0,
#     'is_favorite': False,
#     'post_type': 'post',
#     'text': 'Запутаться в теме условных предложений (Conditional Sentences) очень просто. Но не с этим лайфхаком! Смотрим, запоминаем, шерим друзьям, сохраняем.\n\nМы знаем, что получать знания — это не сидеть и зубрить тему за темой. В английском, как и во многих других областях, есть множество лайфхаков для понимания, изучения и запоминания. Мы их знаем и готовы с вами делиться!\n\nС вас два простых шага:\nШаг 1. Запишитесь на бесплатный курс «Английский для ленивых».\nШаг 2. 10 дней подряд получайте такие же ненапряжные лайфхаки, чтобы незаметно прокачивать английский язык.\nСсылочка на курс: https://go.skyeng.ru/lazy_ness_vk',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662642113,
#        'id': 457282745,
#        'owner_id': -51890028,
#        'access_key': '72f6259e39bc0316b4',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-47.userapi.com/impg/kecS__Nv87P0H8olV6npjn7N444E4G5kNzwTUQ/v_mguFWvOfE.jpg?size=60x75&quality=95&sign=bae2f2dba7d8dc9bdb7db881e95533c5&c_uniq_tag=2npjjtQSa3C5xJVB8jERlNO-0GuxigpqVd3mRTz2mvs&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun9-47.userapi.com/impg/kecS__Nv87P0H8olV6npjn7N444E4G5kNzwTUQ/v_mguFWvOfE.jpg?size=104x130&quality=95&sign=00de7c87f0bea7d8a5e0919a44f396fb&c_uniq_tag=Q0AD75i62As6qWAvXqOtLG_p-djQV-Sop4-WQmv76co&type=album',
#          'type': 'm',
#          'width': 104},
#         {'height': 604,
#          'url': 'https://sun9-47.userapi.com/impg/kecS__Nv87P0H8olV6npjn7N444E4G5kNzwTUQ/v_mguFWvOfE.jpg?size=483x604&quality=95&sign=ed23d46f6f1a2b723b371a0d306e8b67&c_uniq_tag=NjVZuj8ZaMqsOx7bmWJN0BTzLH2-TUP9cQEgyo3zfqo&type=album',
#          'type': 'x',
#          'width': 483},
#         {'height': 807,
#          'url': 'https://sun9-47.userapi.com/impg/kecS__Nv87P0H8olV6npjn7N444E4G5kNzwTUQ/v_mguFWvOfE.jpg?size=646x807&quality=95&sign=c6cbc08826c2ea958c86a9a5883444c0&c_uniq_tag=I0sMtrPfRAhSH5zuavfKHdW86xSYCh0HoPVbAS2A9so&type=album',
#          'type': 'y',
#          'width': 646},
#         {'height': 1080,
#          'url': 'https://sun9-47.userapi.com/impg/kecS__Nv87P0H8olV6npjn7N444E4G5kNzwTUQ/v_mguFWvOfE.jpg?size=864x1080&quality=95&sign=186c5c1b42a44508a15ac67bac846a66&c_uniq_tag=kfrnyBfDnwnR8V6whPK-F6LRUOGXIS8MnjFVxqtgLZA&type=album',
#          'type': 'z',
#          'width': 864},
#         {'height': 1350,
#          'type': 'p',
#          'width': 200},
#         {'height': 400,
#          'url': 'https://sun9-82.userapi.com/impg/OxLWKtHbV-zqAMjZLKdnfuOtYEeXdDElRMSDLQ/D05JG8MD1NM.jpg?size=320x400&quality=95&sign=d985180fb9949ba61a6b83662648cb97&c_uniq_tag=sbjYDzV7Xfw9aT2hWUyHdvVfEeEpq0zeKPf1QUBHGAs&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-82.userapi.com/impg/OxLWKtHbV-zqAMjZLKdnfuOtYEeXdDElRMSDLQ/D05JG8MD1NM.jpg?size=510x637&quality=95&sign=78976e5b68ffd772640e3b12fc9ed920&c_uniq_tag=KijbeQKFXZ9n6-nLFxcZ7wQY5sLpNt8T-qhblBsfTgY&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662642113,
#        'id': 457282748,
#        'owner_id': -51890028,
#        'access_key': '765ba8d23fae5744b9',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-47.userapi.com/impg/ryFLw9gUcrY672qYZdMxjPTVffTKoCa2MIYNfA/KMrQlbwt7wk.jpg?size=60x75&quality=95&sign=f27a6abb6bd1b8f266c1263802cead0a&c_uniq_tag=dJU9D_5Z84g4tL9Xt-6jV29_dsW4dmNBNCXVDl64JlM&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun9-47.userapi.com/impg/ryFLw9gUcrY672qYZdMxjPTVffTKoCa2MIYNfA/KMrQlbwt7wk.jpg?size=104x130&quality=95&sign=c27cb5f2bd4e6604b6b1c00dd8e85fc9&c_uniq_tag=ukj9u3gF7WOyJaJBfEjuZ_KKUZBES1ig1qvh2oc_qHs&type=album',
#          'type': 'm',
#          'width': 104},
#         {'height': 604,
#          'url': 'https://sun9-47.userapi.com/impg/ryFLw9gUcrY672qYZdMxjPTVffTKoCa2MIYNfA/KMrQlbwt7wk.jpg?size=483x604&quality=95&sign=de9313af32a03d1f73ff318e9c17ac2e&c_uniq_tag=STtpq_Zb84JyONhjC6k3OLaap8exdhsaATybivMT1RA&type=album',
#          'type': 'x',
#          'width': 483},
#         {'height': 807,
#          'url': 'https://sun9-47.userapi.com/impg/ryFLw9gUcrY672qYZdMxjPTVffTKoCa2MIYNfA/KMrQlbwt7wk.jpg?size=646x807&quality=95&sign=8f5a18212a8da876b6620ac7895bf4d8&c_uniq_tag=lATQKK4EGCEK3bdiK7OCL85YC5UCGbIcPPPo-DzKrZk&type=album',
#          'type': 'y',
#          'width': 646},
#         {'height': 1080,
#          'url': 'https://sun9-47.userapi.com/impg/ryFLw9gUcrY672qYZdMxjPTVffTKoCa2MIYNfA/KMrQlbwt7wk.jpg?size=864x1080&quality=95&sign=f19a1928ed7bacb975721ff1d6776db9&c_uniq_tag=e-n78Lwy-ol2r0dqZIFNTpqeNRDjdMac_jKT3LciGdw&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662642113,
#        'id': 457282750,
#        'owner_id': -51890028,
#        'access_key': 'be747c5392326b78f3',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=60x75&quality=95&sign=ccd2e57916dc83c7edc9f57e33852d0e&c_uniq_tag=mRRrTxyy0J_52EuH3oUEToUNv5_G7i-kdKm0ryOIors&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=104x130&quality=95&sign=88d2529831ce05f52e769380fdb296d4&c_uniq_tag=AqIHzgnUWZO0_dJ1_jTNG5DmH14pbpICnP0_Q0F9CNA&type=album',
#          'type': 'm',
#          'width': 104},
#         {'height': 604,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=483x604&quality=95&sign=99bc8ccb81034d95da8289c7454bd5f6&c_uniq_tag=H5yqErJfN9PPoKS0eU3IVD2GjscA3yTEOgcuZ-MLzPk&type=album',
#          'type': 'x',
#          'width': 483},
#         {'height': 807,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=646x807&quality=95&sign=1b3a5017438d083e05982eb09e48e50d&c_uniq_tag=jmaYlPWEB3pDvYYK6hcqEnC2na2dt_v2rhBHabEA86Q&type=album',
#          'type': 'y',
#          'width': 646},
#         {'height': 1080,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=864x1080&quality=95&sign=11a15393754823345d65286df3865be7&c_uniq_tag=CK-k9aKQO1ULd38T-7lv1icmXzfxqIGVGfKSCKLdQYs&type=album',
#          'type': 'z',
#          'width': 864},
#         {'height': 1350,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=1080x1350&quality=95&sign=0cbff54709ad0bb203b708d89701b72e&c_uniq_tag=ikDYti7xpgUSNiDHY8ZOvPnnjOTjC2mYybRhdDLohqM&type=album',
#          'type': 'w',
#          'width': 1080},
#         {'height': 162,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=130x162&quality=95&sign=a441555381c0e0304926d9cc60bb1123&c_uniq_tag=Fa2A0giaqHM7YFHVbXzjlWOCSZcBLH2uhRJBL9APpt8&type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 250,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=200x250&quality=95&sign=080fb0e155ef74fd4b338128e317e7eb&c_uniq_tag=V-J2Nl9UdBu4cYWlcMECnm_ak-O45rlSiZ3OwweOTok&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 400,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=320x400&quality=95&sign=5c4b2dc29929fca737d021e3518711d1&c_uniq_tag=wJjhCYtmqEbE7HgZPaXs4-jZhNSd-Fw1wiQLgLrqq6s&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-9.userapi.com/impg/qF7_UqdL3Sb6XoB5fbFXPeBzrmkDdWVQXwYYZQ/4ifxMuR33Po.jpg?size=510x637&quality=95&sign=4124e3b53b6fccc6c97bf49ddd6bfe62&c_uniq_tag=GFy39oAvG1kn_F_Q-nbwRUOHJt9liqt06mUv1Gxd6tI&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662642113,
#        'id': 457282751,
#        'owner_id': -51890028,
#        'access_key': 'f268bebe8c5e06cb5b',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=60x75&quality=95&sign=c8a583bc08a63a8bfd86d36eb7d636d7&c_uniq_tag=WEY_zcTcO84q-4OkxDLBBDL-zKWL6ZBm3ifBhxsHeO4&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=104x130&quality=95&sign=e1088fab7f3538cb57cb36a4e95ed3f9&c_uniq_tag=KEE2EjntzASiLmmuy8Xu5kMAeTSZjLLD4eZRvZI8pmE&type=album',
#          'type': 'm',
#          'width': 104},
#         {'height': 604,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=483x604&quality=95&sign=9642be445aa4ee7049adc10ee7deca54&c_uniq_tag=MkD-KiubzZ_ne3x7LziV6U6yuxCJS0cuc73KWzSqSTo&type=album',
#          'type': 'x',
#          'width': 483},
#         {'height': 807,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=646x807&quality=95&sign=ee99f195cee6307590f810be56d32226&c_uniq_tag=mqC64nPdIS4fi0aCJFVbuuzCX_ZUF16d_pYnBbaPD6c&type=album',
#          'type': 'y',
#          'width': 646},
#         {'height': 1080,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=864x1080&quality=95&sign=7abf698b76e52c7312f3cd120b69cc5d&c_uniq_tag=A-6mEsKyr5jkrEkXQZB0FnogdZqpNinTUraCpEGrPCE&type=album',
#          'type': 'z',
#          'width': 864},
#         {'height': 1350,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=1080x1350&quality=95&sign=3edd05e39c593bab87800375b24600db&c_uniq_tag=hBKQ3musZoocmrjHCFdnYrkfZYDXt9WRSHhdDsRdATE&type=album',
#          'type': 'w',
#          'width': 1080},
#         {'height': 162,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=130x162&quality=95&sign=30be9e89010419153fc36e7414d4eb37&c_uniq_tag=eIfT_qic02dhPS-PUgnVx4TYb8FIQWh07k9JJP_gwv4&type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 250,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=200x250&quality=95&sign=baefb26940a06c2aa5b1e4a274e1eacd&c_uniq_tag=ZFo9QWICBeYWTrmwB9AWdHYuHdcOfHVAYv7r4IZ_EJc&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 400,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=320x400&quality=95&sign=eb32d71dc1733617322850bda877767a&c_uniq_tag=yaYdnytfsSdufMw_CknqumoXE3tAsHWqlHXdE-uZxD0&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-86.userapi.com/impg/llajI2fwJzGnHp3t-g7ZE9ZFUDn_JtB3UV-YlA/DEz6PixcnYU.jpg?size=510x637&quality=95&sign=5b53b7c4227f88b7cd958a249ec354c0&c_uniq_tag=ppRMPcbyKAvb3SE83YXyHh3YCFgOBEQ5nip2FSbnYxA&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662642113,
#        'id': 457282752,
#        'owner_id': -51890028,
#        'access_key': '5376cedd28ca19cb62',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-31.userapi.com/impg/V8erWtWAc26YvhrR_8tzzQ4cKw-8PlXH4hkzIw/xLja7QzZQuA.jpg?size=60x75&quality=95&sign=ed17e6469e64872ebb1dedd8113ef8a8&c_uniq_tag=Aks67tchBnjzVT3Im0NF_2KwAtpMciSy5XozRwTj5PE&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-31.userapi.com/impg/V8erWtWAc26YvhrR_8tzzQ4cKw-8PlXH4hkzIw/xLja7QzZQuA.jpg?size=510x637&quality=95&sign=61c72662d6d502207d1ec49bd84086c5&c_uniq_tag=5IFRbk5PiJu3GtUWrt6PMA5ZbR5aeFMCxDgauEqaqEg&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'link',
#       'link': {'url': 'https://go.skyeng.ru/lazy_ness_vk',
#        'title': 'Запишитесь на бесплатный курс',
#        'description': '',
#        'target': 'internal',
#        'photo': {'album_id': -28,
#         'date': 1662642113,
#         'id': 457407129,
#         'owner_id': 2000011177,
#         'sizes': [{'height': 90,
#           'url': 'https://sun9-57.userapi.com/3zjSlMCA57G_hgB9bjTNlyFP7uTRC29OzlnHew/lw3rAZpDHsc.jpg',
#           'type': 'a',
#           'width': 200},
#          {'height': 179,
#           'url': 'https://sun9-80.userapi.com/NvN-pre37WAFxDDKJBe7XDlYGAzXZQN6rWrFrA/K_5zkST4b5s.jpg',
#           'type': 'b',
#           'width': 400},
#          {'height': 200,
#           'url': 'https://sun9-13.userapi.com/wlOUtlgnRfB4owlLhrMrQhZb2eX3RC58tfaXUA/NuCbjDrCu1o.jpg',
#           'type': 'c',
#           'width': 200},
#          {'height': 100,
#           'url': 'https://sun9-58.userapi.com/bZaeriiTUaXnf77QF2XZAEPu43c-BVP1kNJ_NA/R-NWi2l-8bs.jpg',
#           'type': 'd',
#           'width': 100},
#          {'height': 50,
#           'url': 'https://sun9-77.userapi.com/g4OkqmbUVRRWpn_K8J1SZ3PbOkQYogZ1_ov3kg/5tBK_rqnKBY.jpg',
#           'type': 'e',
#           'width': 50},
#          {'height': 480,
#           'url': 'https://sun9-38.userapi.com/impg/jdP9W6OqcnB6xCF-_yWOEVhv4ieKnhPQUgBR0w/J5a2Zf_Erkw.jpg?size=1072x480&quality=96&sign=f9c700802b789dd6f051e3abba995443&c_uniq_tag=B3XD98aM7F0cJO6leVQX8_SmY3J8EXIJOmABEMAz5S0&type=share',
#           'type': 'k',
#           'width': 1072},
#          {'height': 240,
#           'url': 'https://sun9-38.userapi.com/impg/jdP9W6OqcnB6xCF-_yWOEVhv4ieKnhPQUgBR0w/J5a2Zf_Erkw.jpg?size=537x240&quality=96&sign=fc07d12b07608205132f2d0d33c216d0&c_uniq_tag=XdzroAgQuij4Nmfgt63jBTIgjRSPYz4jHgJ4OpJn93k&type=share',
#           'type': 'l',
#           'width': 537},
#          {'height': 636,
#           'url': 'https://sun9-28.userapi.com/45y9zz7IxU-rqVJK12QKuLMxutyYTs4vnhtKaA/kxCcdGO14Fw.jpg',
#           'type': 'o',
#           'width': 1420}],
#         'text': '',
#         'user_id': 100,
#         'has_tags': False},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 105, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 96, 'user_reposted': 0},
#     'views': {'count': 6895},
#     'donut': {'is_donut': False},
#     'short_text_rate': 0.8,
#     'carousel_offset': 0,
#     'hash': 'JFKxl0MrT9gEHWid0P32RoAt4PA'},
#    {'id': 89803,
#     'from_id': -51890028,
#     'owner_id': -51890028,
#     'date': 1662564591,
#     'marked_as_ads': 0,
#     'is_favorite': False,
#     'post_type': 'post',
#     'text': 'Мы очень хотим начать знакомить вас с теми, кто создает Skyeng каждый день! \n\nСегодня расскажем о Насте Качулиной, девушке, благодаря которой наш журнал об английском Skyeng Magazine наполняется статьями и тестами, а телеграм-канал — мемами и кружочками от Дэни, Джордана и Ани Шенцевой 💙\n \nКто такая, чем живет, как оказалась в Skyeng и насколько хорошо знает английский? Велкам к прочтению!\n\nПростое дружеское напоминание: начать заниматься в Skyeng очень просто. Запишитесь на бесплатное вводное занятие через [https://vk.me/skyeng|сообщения группы] или по ссылке: go.skyeng.ru/firstlesson7_vk\n\nНа уроке мы определим ваш уровень языка и подберем оптимальный план изучения английского в соответствии с вашими целями.',
#     'attachments': [{'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662563987,
#        'id': 457282737,
#        'owner_id': -51890028,
#        'access_key': 'd1cec5a0a34d047054',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=60x75&quality=95&sign=aad2e7a7f01ca60728b124062d48c222&c_uniq_tag=xUQwyDCBDQg09AvVBRoi2lmfPk7qZ112x5YEg3XKBXc&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=104x130&quality=95&sign=684ae957e84b826ad2e43d3789795205&c_uniq_tag=HUrNUMtmjtIkq3ujvBacCJ2RDCegsFBHV0SxCYJUA6Q&type=album',
#          'type': 'm',
#          'width': 104},
#         {'height': 604,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=483x604&quality=95&sign=7ba35ea16ffca5e08ef1ec2a10b048f3&c_uniq_tag=TfT2eZckI40ivaB6xsgOwUNEfUKwKqj53UIahd6K41M&type=album',
#          'type': 'x',
#          'width': 483},
#         {'height': 807,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=646x807&quality=95&sign=828b1ccafe1350ff585586ca576a5ee4&c_uniq_tag=25MVxhT9DRgJvfGMFU3e710G615dOGrZzTsVLyLpwDY&type=album',
#          'type': 'y',
#          'width': 646},
#         {'height': 1080,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=864x1080&quality=95&sign=a13abe13ad4fe6b65dac3b558b07af9e&c_uniq_tag=Rcqqu_CBjd8m8znViO_h8LFPTf9AkG_tCOuTwxgRKdM&type=album',
#          'type': 'z',
#          'width': 864},
#         {'height': 1350,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=1080x1350&quality=95&sign=e0ef6701436d6bacb34c97a705e80331&c_uniq_tag=d3w7Z4O067KXI7FvlxjTwKW5RgNuATynBTNkU7Ln1_4&type=album',
#          'type': 'w',
#          'width': 1080},
#         {'height': 162,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=130x162&quality=95&sign=06f9ee6930691a73f201afe9a2a15b04&c_uniq_tag=c5ncd_hc8KHPgC6i2xxIwtpBUfxpXSWgtPpEZRPiNUM&type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 250,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=200x250&quality=95&sign=0694ed109bedaeb9314e4d5c5f83db94&c_uniq_tag=scB5vwkEGd5W26cxCSNw6piSndSifEssLe9dlkqqiTk&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 400,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=320x400&quality=95&sign=a73cca715a7ea5ef8f44c9c42d583ce2&c_uniq_tag=nrZmPh5LIcAJJPMqz2f9v76bGVCQlCnPTOh_E4Ughp8&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-17.userapi.com/impg/bIj-IFtFmG0G0_v8TQo1pM7etqcqrAco9felgQ/e5xrL7OoMDU.jpg?size=510x637&quality=95&sign=5cc9f6ea02cedcf0e4c16e5b5bc49b66&c_uniq_tag=QkLzvZfWVusILLEm5fsRy1eeOjMzNVK74-Srqw1e6So&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662563987,
#        'id': 457282738,
#        'owner_id': -51890028,
#        'access_key': 'dcde088e507d63a837',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-33.userapi.com/impg/tRtDZ8R8wDCbC0wJgUJtblvGVF84JU3VgdnsXA/OCVLxDtPqGA.jpg?size=60x75&quality=95&sign=9af16df2fc9b3984262f50d8bdbb50d3&c_uniq_tag=7w-LKzSPJFatRZeD3Fht3fBxhYJ-bc1FHQCNKZXD3ao&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#         {'height': 637,
#          'url': 'https://sun9-33.userapi.com/impg/tRtDZ8R8wDCbC0wJgUJtblvGVF84JU3VgdnsXA/OCVLxDtPqGA.jpg?size=510x637&quality=95&sign=ac069cda24f00958c4f0175ece3ea774&c_uniq_tag=n2CBsQas-OAoU69V-wMmD-nWuG-lt2hee7i-dAQd4lo&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1662563987,
#        'id': 457282739,
#        'owner_id': -51890028,
#        'access_key': '58e0a63acc3c19c2e3',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-54.userapi.com/impg/oIseRuwnm3YXo1zIzh2b110xbrIvtKIiz9MHVA/HSKlKB58PDk.jpg?size=60x75&quality=95&sign=455a0bed2b5a8b14a7b14086eb4b5e98&c_uniq_tag=GujuF_T4F8YgxPGSSSMnP6D5ICmNuhtD5g9fHNzyHag&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun9-54.userapi.com/impg/oIseRuwnm3YXo1zIzh2b110xbrIvtKIiz9MHVA/HSKlKB58PDk.jpg?size=104x130&quality=95&sign=b223b4acde3137d1a8730d7eda07b09d&c_uniq_tag=B6EQcsxpWq6n5-6eBMbDNzh-oFcAV6r3vK78dTh2oVA&type=album',
#          'type': 'm',
#          'width': 104},
#         {'height': 604,
#          'url': 'https://sun9-54.userapi.com/impg/oIseRuwnm3YXo1zIzh2b110xbrIvtKIiz9MHVA/HSKlKB58PDk.jpg?size=483x604&quality=95&sign=78b6af1b6dc4b2d5114f1d743a06e623&c_uniq_tag=d4dYHrpifUiFZAB0ehve8dV0oRkoFuWJkgzEVbhHJSM&type=album',
#          'type': 'x',
#          'width': 483},
#         {'height': 807,
#          'url': 'https://sun9-54.userapi.com/impg/oIseRuwnm3YXo1zIzh2b110xbrIvtKIiz9MHVA/HSKlKB58PDk.jpg?size=646x807&quality=95&sign=28a2c968f87e5106a02069f1a628a076&c_uniq_tag=OnGaGNrSg6mT1Lte0Zkr5L7g7-nX1Ds0-GeQ8j6sYnU&type=album',
#          'type': 'y',
#          'width': 646},
#         {'height': 1080,
#          'url': 'https://sun9-54.userapi.com/impg/oIseRuwnm3YXo1zIzh2b110xbrIvtKIiz9MHVA/HSKlKB58PDk.jpg?size=864x1080&quality=95&sign=102f16a7d5ea7c0c378793f4a0131bb0&c_uniq_tag=IiJLLM2QkygfFubiWDWyuGMBMtuC7spPrsxe7BJjW0c&type=album',
#          'type': 'z',
#          'width': 864},
#         {'height': 1350,
#          'url': 'https://sun9-54.userapi.com/impg/oIseRuwnm3YXo1zIzh2b110xbrIvtKIiz9MHVA/HSKlKB58PDk.jpg?size=1080x1350&quality=95&sign=977103bc1379fbf7b26f387af1fe9b0f&c_uniq_tag=eQjP9Fwn0hrPCB7bE5xj3UPYnyrJ8XHtWUAIKwu98y0&type=album',
#          'type': 'w',
#          'width': 1080},
#         {'height': 162,
# ...
#          'type': 'r',
#          'url': 'https://sun9-72.userapi.com/impg/9NiBrs7D_4PgqJtOhdL1TQMku555uEjsX1ZGvA/alLLYypx6HM.jpg?size=200x250&quality=95&sign=66a0bc2afce7794027f85edb8cdd0f40&c_uniq_tag=KYyn3dSHPNcg-e7qvhkYWL0mn7fsPukYTl-Q9Mp6gXA&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 400,
#          'url': 'https://sun9-72.userapi.com/impg/9NiBrs7D_4PgqJtOhdL1TQMku555uEjsX1ZGvA/alLLYypx6HM.jpg?size=320x400&quality=95&sign=1c951ca5a7079ccfee0269b20a8bae35&c_uniq_tag=RZ4AY8ohWvyy0Ngtui6iv85pl2kYjgILrnjHkwNmdJ0&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-72.userapi.com/impg/9NiBrs7D_4PgqJtOhdL1TQMku555uEjsX1ZGvA/alLLYypx6HM.jpg?size=510x637&quality=95&sign=be0afed081d3ce732e2abdf01a31ed3b&c_uniq_tag=tGB7Q0gfG6wvLb5_vlUm7oEs04dUYmMo90PrEvW_Mtk&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1656145604,
#        'id': 457281626,
#        'owner_id': -51890028,
#        'access_key': '1992776bf4eb6534aa',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=60x75&quality=95&sign=0171fc8a429a7e79276c7bfd20408dc4&c_uniq_tag=uh8XrA3cwwfjjo0fuaTJl19UXPzFB5jhoTbeHBalKA8&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=104x130&quality=95&sign=71375a6b04a7130039b2ac311f0e7178&c_uniq_tag=igr2Tqwh8ssYNeAQ3fEJHXitAJ9m7jROgixwnAuKg_s&type=album',
#          'type': 'm',
#          'width': 104},
#         {'height': 604,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=483x604&quality=95&sign=043cc039846ba5218748bef53e81f107&c_uniq_tag=MrAZrqbIn-h_ZS93cO7tcqSd4uYcCjo7c-jKBNgfio4&type=album',
#          'type': 'x',
#          'width': 483},
#         {'height': 807,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=646x807&quality=95&sign=2188bcd4e77cdf578cc0edd8322914b9&c_uniq_tag=hoJiLGEOiOd-AuS3nuTcMFmvU5dKj2fwK--BL7OuRXk&type=album',
#          'type': 'y',
#          'width': 646},
#         {'height': 1080,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=864x1080&quality=95&sign=b3df87e79a7a37ae93f45fe9653cb766&c_uniq_tag=4WN53tPSSvuZBGXVk96ZGdm1KXfJESpKZsek2RTg-UM&type=album',
#          'type': 'z',
#          'width': 864},
#         {'height': 1350,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=1080x1350&quality=95&sign=d04c2e367fe2c07deeefe9e690d070e6&c_uniq_tag=4_h1DzTIegFNtnjX1peKKpoDlo1De2wJurESdPvCbH0&type=album',
#          'type': 'w',
#          'width': 1080},
#         {'height': 162,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=130x162&quality=95&sign=d4c75a69b3f70ab29b24b8a14dcaa94b&c_uniq_tag=Yk7c8B3ZqQmh0QB9W8Yvmw950JadqBUnlevNqzlm3eI&type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 250,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=200x250&quality=95&sign=0bf4e1938afe843e45784fcfd21293df&c_uniq_tag=PtXF7m68AJY_Qb1KrS6kJu3efllQma67XtY_FL3zM_s&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 400,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=320x400&quality=95&sign=e55f44153e7696e74c03bc45760fba74&c_uniq_tag=vn0z9OCFW0Larp-toXUb6duo2Edqz8CVbOLHppIQe5U&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-87.userapi.com/impg/Wyqs83o6QaUdiAJ-OmnXPaoVFx3ZaV5Jh9rVBA/0RtUk21LR2Q.jpg?size=510x637&quality=95&sign=84ff1cdc44636b9dfd00dce67d3d2a0e&c_uniq_tag=d85t671bwe9-0oXP5PuC2x82o4cVmS6TmHRGBapMiII&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1656145604,
#        'id': 457281627,
#        'owner_id': -51890028,
#        'access_key': '5719350988d57fc5b1',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-63.userapi.com/impg/vhSPvxnxdObWXDRbWUr0fTUCsKPN9pSl4jgyZA/tu9Lta2qBHU.jpg?size=60x75&quality=95&sign=84f33d899a53673010d82979aa17510e&c_uniq_tag=tYewMlgrK2FLVCOaHjTZ81TAPiaFvehefDGDhptqG1c&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-63.userapi.com/impg/vhSPvxnxdObWXDRbWUr0fTUCsKPN9pSl4jgyZA/tu9Lta2qBHU.jpg?size=510x637&quality=95&sign=d529259577cb6b283f9dc5f7d7c7f899&c_uniq_tag=iXKBYYuFIbQIFRdvKgY9XmMeZrb4jt5psJMlqoVSD44&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'photo',
#       'photo': {'album_id': -7,
#        'date': 1656145604,
#        'id': 457281628,
#        'owner_id': -51890028,
#        'access_key': '6b159687b7c1072cd0',
#        'sizes': [{'height': 75,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=60x75&quality=95&sign=672d5a1da832c877b1dfef23c093ba53&c_uniq_tag=xw2u68c2ZkKXcDg4tG076k4KeT7Hin4HcA8ue2M8p6w&type=album',
#          'type': 's',
#          'width': 60},
#         {'height': 130,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=104x130&quality=95&sign=c11c422a19efc4b79f43ccd03b8a367f&c_uniq_tag=HXJBLl5kiQWqQE9kmtQU-MqdfexP6VXCuDpjfmWcoWw&type=album',
#          'type': 'm',
#          'width': 104},
#         {'height': 604,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=483x604&quality=95&sign=825c16c2b246af4e9fab026c7adaf855&c_uniq_tag=pULhqUNpzju1FM_YMc75-zTvBpJUxEzEOAYQnN-dFkQ&type=album',
#          'type': 'x',
#          'width': 483},
#         {'height': 807,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=646x807&quality=95&sign=c30a9fc9acd449776b6341eebce03df7&c_uniq_tag=zZmInSH4zIAermyUa8-OsF9bOqEjh0Zf_7_9SVOW5lc&type=album',
#          'type': 'y',
#          'width': 646},
#         {'height': 1080,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=864x1080&quality=95&sign=82894c2d5a754880f0e1186119903600&c_uniq_tag=Z0EqeILTdG5ynGVFg5cvHhxjqC3RAdJQJOXni78175I&type=album',
#          'type': 'z',
#          'width': 864},
#         {'height': 1350,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=1080x1350&quality=95&sign=2f0d93c1ee62212f3f9bda25e18deaf3&c_uniq_tag=QXCGuun2iVx53Tslv_arWIxvQCIIDTUqg2Q8kJ3b1m4&type=album',
#          'type': 'w',
#          'width': 1080},
#         {'height': 162,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=130x162&quality=95&sign=4fc26c3838ff459e308a221086171c88&c_uniq_tag=mYQ29wR6d_xahTORBuZfwfkD6AGbBZRwUbWYoEJbneo&type=album',
#          'type': 'o',
#          'width': 130},
#         {'height': 250,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=200x250&quality=95&sign=128f55568a595fe49f2f8209ec79e6f4&c_uniq_tag=fKxhe_Uro7j6x10Drxvk1rzgsxzZvD2AD9hrdKJyU-s&type=album',
#          'type': 'p',
#          'width': 200},
#         {'height': 400,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=320x400&quality=95&sign=98582a0334ec571b027c0651f3a47fab&c_uniq_tag=JGo8aLLd0k67lorZPFXyMzwPJrHNTU5nLqFxUAdLZdg&type=album',
#          'type': 'q',
#          'width': 320},
#         {'height': 637,
#          'url': 'https://sun9-18.userapi.com/impg/Sp4jPfHh8Miz_uGBoH9iJfT1sNLYFNSzR4H3bA/WLUZuU7wJ0I.jpg?size=510x637&quality=95&sign=4114cd811c64563d7b0c9f4111d2e9fe&c_uniq_tag=diW4ketwVREtjVAzZPiZ2Qt3w4ZigzyShOnVTDu7QSE&type=album',
#          'type': 'r',
#          'width': 510}],
#        'text': '',
#        'user_id': 100,
#        'has_tags': False}},
#      {'type': 'link',
#       'link': {'url': 'https://go.skyeng.ru/summer_sale',
#        'title': 'Успейте за лето | скидка до 55% от Skyeng',
#        'description': 'Акция "Успейте за лето". Скидки до 55% на уроки английского',
#        'target': 'internal',
#        'photo': {'album_id': -28,
#         'date': 1656145604,
#         'id': 457384330,
#         'owner_id': 2000037567,
#         'sizes': [{'height': 89,
#           'url': 'https://sun9-1.userapi.com/slHJGtUnYBFXU11mBEiN8Or65dLoOqowJxKUlQ/mI3AvF5ZOks.jpg',
#           'type': 'a',
#           'width': 200},
#          {'height': 179,
#           'url': 'https://sun9-42.userapi.com/ZGL33G768VBQgy0bNXdCYTtyoeZJegiK24V2TQ/o8X2hrs0IuU.jpg',
#           'type': 'b',
#           'width': 400},
#          {'height': 200,
#           'url': 'https://sun9-60.userapi.com/p-J4bYPguQc7xVnzWu9YhMesfvXtvwFA4XThGA/F2JqnhXSI9M.jpg',
#           'type': 'c',
#           'width': 200},
#          {'height': 100,
#           'url': 'https://sun9-1.userapi.com/tcveeXbeN46EChR8qnNoS80OLl9Ini-M-IIKfA/SO5NAQnpJzc.jpg',
#           'type': 'd',
#           'width': 100},
#          {'height': 50,
#           'url': 'https://sun9-61.userapi.com/5cOoiCQ1AN_oFRQn20-j4wXY1e7Bn7PbBIDW2w/Qrlcma_eVok.jpg',
#           'type': 'e',
#           'width': 50},
#          {'height': 479,
#           'url': 'https://sun9-49.userapi.com/impg/3zoPJnEH16Hk4hgRZflC1M5gXwWeJMV2lRPMRQ/QMF32qAxjSI.jpg?size=1074x479&quality=96&sign=b6753eb0662f19ee203f4a4bc7c09d98&c_uniq_tag=a721l17dRsNGkERmrzzkAvG-GqD5qkefpVAAfyq4Vds&type=share',
#           'type': 'k',
#           'width': 1074},
#          {'height': 239,
#           'url': 'https://sun9-49.userapi.com/impg/3zoPJnEH16Hk4hgRZflC1M5gXwWeJMV2lRPMRQ/QMF32qAxjSI.jpg?size=537x239&quality=96&sign=4730afb2387707f546bd5f3dd174dbbf&c_uniq_tag=L6rOSO7lXvrd2RrR8Eyc_dcp_VPTalZcGYCpiGRh80k&type=share',
#           'type': 'l',
#           'width': 537},
#          {'height': 783,
#           'url': 'https://sun9-37.userapi.com/wsDIbAj0K-drm7xD5bEgQyl34Z6rjzgLWqmtVw/7wHQgMN5t1M.jpg',
#           'type': 'o',
#           'width': 1754}],
#         'text': '',
#         'user_id': 100,
#         'has_tags': False},
#        'is_favorite': False}}],
#     'post_source': {'type': 'vk'},
#     'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#     'likes': {'can_like': 1, 'count': 28, 'user_likes': 0, 'can_publish': 1},
#     'reposts': {'count': 15, 'user_reposted': 0},
#     'views': {'count': 15109},
#     'donut': {'is_donut': False},
#     'short_text_rate': 0.8,
#     'carousel_offset': 0,
#     'edited': 1656145621,
#     'hash': '2Rn_hA_79fioAer-m-njDCcKnOk'}]}}

# %% [markdown]
# ## Задание 3
#
# Выгрузи в переменную `posts` в формате датафрейма __все записи__ сообщества Skyeng: https://vk.com/skyeng,
#
# 1. Используй цикл `While`
# 2. Для выгрузки __всех записей__ тебе поможет параметр `offset`.
# 3. Записей больше 7000! Не забудь про ограничение "не больше 3 запросов в секунду" от API VK, здесь тебе поможет библиотека `time`

# %%
import time

# %%
# напиши здесь код

offset = 0
max_count = 100
posts = pd.DataFrame()

while True:      
    
    url = 'https://api.vk.com/method/wall.get'
    params = {
        'domain': 'skyeng',
        'access_token': token,
        'v':'5.131',
        'count': max_count,
        'offset': offset
    }
    
    req = requests.get(url=url, 
                       params=params)
    res = req.json()
    
    if len(res['response']['items']) != 0:      
        posts = pd.concat([posts, pd.DataFrame(res['response']['items'])]) 
    else:
        break                                  
    print('Уже скачано', offset, 'записей')
    offset = offset + max_count                 
    time.sleep(0.5)
# Out:
# Уже скачано 0 записей
# Уже скачано 100 записей
# Уже скачано 200 записей
# Уже скачано 300 записей
# Уже скачано 400 записей
# Уже скачано 500 записей
# Уже скачано 600 записей
# Уже скачано 700 записей
# Уже скачано 800 записей
# Уже скачано 900 записей
# Уже скачано 1000 записей
# Уже скачано 1100 записей
# Уже скачано 1200 записей
# Уже скачано 1300 записей
# Уже скачано 1400 записей
# Уже скачано 1500 записей
# Уже скачано 1600 записей
# Уже скачано 1700 записей
# Уже скачано 1800 записей
# Уже скачано 1900 записей
# Уже скачано 2000 записей
# Уже скачано 2100 записей
# Уже скачано 2200 записей
# Уже скачано 2300 записей
# Уже скачано 2400 записей
# Уже скачано 2500 записей
# Уже скачано 2600 записей
# Уже скачано 2700 записей
# Уже скачано 2800 записей
# Уже скачано 2900 записей
# Уже скачано 3000 записей
# Уже скачано 3100 записей
# Уже скачано 3200 записей
# Уже скачано 3300 записей
# Уже скачано 3400 записей
# Уже скачано 3500 записей
# Уже скачано 3600 записей
# Уже скачано 3700 записей
# Уже скачано 3800 записей
# Уже скачано 3900 записей
# Уже скачано 4000 записей
# Уже скачано 4100 записей
# Уже скачано 4200 записей
# Уже скачано 4300 записей
# Уже скачано 4400 записей
# Уже скачано 4500 записей
# Уже скачано 4600 записей
# Уже скачано 4700 записей
# Уже скачано 4800 записей
# Уже скачано 4900 записей
# Уже скачано 5000 записей
# Уже скачано 5100 записей
# Уже скачано 5200 записей
# Уже скачано 5300 записей
# Уже скачано 5400 записей
# Уже скачано 5500 записей
# Уже скачано 5600 записей
# Уже скачано 5700 записей
# Уже скачано 5800 записей
# Уже скачано 5900 записей
# Уже скачано 6000 записей
# Уже скачано 6100 записей
# Уже скачано 6200 записей
# Уже скачано 6300 записей
# Уже скачано 6400 записей
# Уже скачано 6500 записей
# Уже скачано 6600 записей
# Уже скачано 6700 записей
# Уже скачано 6800 записей
# Уже скачано 6900 записей
# Уже скачано 7000 записей
# Уже скачано 7100 записей
# Уже скачано 7200 записей
# Уже скачано 7300 записей
# Уже скачано 7400 записей
# Уже скачано 7500 записей
# Уже скачано 7600 записей
# Уже скачано 7700 записей
# Уже скачано 7800 записей
# Уже скачано 7900 записей
# Уже скачано 8000 записей
# Уже скачано 8100 записей
# Уже скачано 8200 записей

# %%
print('Кол-во записей:', len(posts))
# Out:
# Кол-во записей: 8239

# %%
posts.head()
# Out:
#       id   from_id  owner_id        date  marked_as_ads  is_favorite  \
# 0  89850 -51890028 -51890028  1662710140              0        False
# 1  89807 -51890028 -51890028  1662657213              0        False
# 2  89805 -51890028 -51890028  1662642113              0        False
# 3  89803 -51890028 -51890028  1662564591              0        False
# 4  89784 -51890028 -51890028  1662482127              0        False
#
#   post_type                                               text  \
# 0      post  to declare / proclaim (a period of) mourning —...
# 1      post  Друзья, хотим поделиться классной новостью: се...
# 2      post  Запутаться в теме условных предложений (Condit...
# 3      post  Мы очень хотим начать знакомить вас с теми, кт...
# 4      post  Плавно, не грузя вас сложной и лишней информац...
#
#                                          attachments     post_source  ...  \
# 0  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 1  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 2  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 3  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 4  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
#
#               views                donut short_text_rate  \
# 0    {'count': 724}  {'is_donut': False}             0.8
# 1   {'count': 5658}  {'is_donut': False}             0.8
# 2   {'count': 6895}  {'is_donut': False}             0.8
# 3   {'count': 8503}  {'is_donut': False}             0.8
# 4  {'count': 23129}  {'is_donut': False}             0.8
#
#                           hash carousel_offset  edited copy_history  \
# 0  Ni-5W4wR0zZlEeHTOrpYEELJLoQ             NaN     NaN          NaN
# 1  bLnro8MFqJJ-7oDIdQQV7MPRb0Q             NaN     NaN          NaN
# 2  JFKxl0MrT9gEHWid0P32RoAt4PA             0.0     NaN          NaN
# 3  t037F2EsJ12CN1M0w6sd7FOT-mo             0.0     NaN          NaN
# 4  QNAV-o7WaKJgEyrzNuIrCHqhnJw             0.0     NaN          NaN
#
#    signer_id  zoom_text  geo
# 0        NaN        NaN  NaN
# 1        NaN        NaN  NaN
# 2        NaN        NaN  NaN
# 3        NaN        NaN  NaN
# 4        NaN        NaN  NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Задание 4
#
# Выгрузи 50 самых популярных постов. Метрикой популярности мы считаем сумму лайков, репостов и комментариев.
#
# 1. Создай столбцы с числовыми значениями для лайков, репостов и комментариев и забери из словаря только значение по ключу `count`
# 2. Создай отдельный столбец, где будет сумма пользовательских активностей для каждого поста
# 3. Отсортируй дата-фрейм по столбцу с суммой пользовательских активностей
# 4. Выбери 50 самых популярных постов
#
# Если задание кажется легким, реализуй тот же код с `lambda` функцией.

# %%
def comments_cnt(x):
    return x['count']

posts['comments_count'] = posts['comments'].apply(comments_cnt)

# %%
posts['likes_count'] = posts['likes'].apply(lambda x: x['count'])

# %%
posts['reposts_count'] = posts['reposts'].apply(lambda x: x['count'])

# %%
# вытащи из словарей столбцов comments, likes, reposts только нужные значения

# заполни даными с прошлого шага новые столбцы
posts['comments_count'] = 
posts['likes_count'] = 
posts['reposts_count'] =
# Out:
#   Input In [15]
#     posts['comments_count'] =
#                               ^
# SyntaxError: invalid syntax

# %%
# заполни данными столбец с суммой по всем активностям

posts['activity'] = posts['comments_count'] + posts['likes_count'] + posts['reposts_count']

# %%
posts = posts.sort_values(by='activity', ascending = False)

# %%
posts = posts.head(50)

# %%
posts.head(5)
# Out:
#        id   from_id  owner_id        date  marked_as_ads  is_favorite  \
# 38  63081 -51890028 -51890028  1602590409              0        False
# 85  25259 -51890028 -51890028  1554800244              0        False
# 32    977 -51890028 -51890028  1416930109              0        False
# 73  75933 -51890028 -51890028  1604923204              0        False
# 64  42960 -51890028 -51890028  1568444249              0        False
#
#    post_type                                               text  \
# 38      post  КОНКУРС! Выиграйте уроки английского и бьюти-б...
# 85      post  Через 15 дней вы накачаете пресс и выучите анг...
# 32      post  100 полезных английских фраз\nЭти фразы выруча...
# 73      post  КОНКУРС! Выиграйте уроки английского и боксы с...
# 64      post  😑Предлоги в английском — больная тема для всех...
#
#                                           attachments     post_source  ...  \
# 38  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 85  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 32  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 73  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
# 64  [{'type': 'photo', 'photo': {'album_id': -7, '...  {'type': 'vk'}  ...
#
#    carousel_offset        edited copy_history signer_id zoom_text  geo  \
# 38             0.0           NaN          NaN       NaN       NaN  NaN
# 85             0.0  1.554800e+09          NaN       NaN       NaN  NaN
# 32             0.0  1.416991e+09          NaN       NaN       NaN  NaN
# 73             0.0           NaN          NaN       NaN       NaN  NaN
# 64             0.0  1.568449e+09          NaN       NaN       NaN  NaN
#
#    comments_count  likes_count  reposts_count activity
# 38          10962          117              2    11081
# 85            239         7007           1334     8580
# 32              0         4012            972     4984
# 73           2891          133              6     3030
# 64             50         1932            449     2431
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Задание 5
#
# __Почисти данные, сохрани результат в файл для отправки копирайтерам__
#
# 1. Отфильтруй в датафрейме только нужные столбцы:
#     - дата поста
#     - текст поста
#     - количество комментариев
#     - количество лайков
#     - количество репостов
#     - общее количество пользовательских активностей
#
# 2. Выгрузи датафрейм в .csv файл

# %%
# напиши здесь код
posts = posts [['date', 'text', 'comments_count', 'likes_count', 'reposts_count', 'activity']]

# %%
posts.head(5)
# Out:
#           date                                               text  \
# 38  1602590409  КОНКУРС! Выиграйте уроки английского и бьюти-б...
# 85  1554800244  Через 15 дней вы накачаете пресс и выучите анг...
# 32  1416930109  100 полезных английских фраз\nЭти фразы выруча...
# 73  1604923204  КОНКУРС! Выиграйте уроки английского и боксы с...
# 64  1568444249  😑Предлоги в английском — больная тема для всех...
#
#     comments_count  likes_count  reposts_count  activity
# 38           10962          117              2     11081
# 85             239         7007           1334      8580
# 32               0         4012            972      4984
# 73            2891          133              6      3030
# 64              50         1932            449      2431

# %%
def convert_utc_time (unix_time):
    return time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(unix_time))

# %%
posts['date'] = posts['date'].apply(convert_utc_time)
posts.head()
# Out:
#                    date                                               text  \
# 38  2020-10-13 15:00:09  КОНКУРС! Выиграйте уроки английского и бьюти-б...
# 85  2019-04-09 11:57:24  Через 15 дней вы накачаете пресс и выучите анг...
# 32  2014-11-25 18:41:49  100 полезных английских фраз\nЭти фразы выруча...
# 73  2020-11-09 15:00:04  КОНКУРС! Выиграйте уроки английского и боксы с...
# 64  2019-09-14 09:57:29  😑Предлоги в английском — больная тема для всех...
#
#     comments_count  likes_count  reposts_count  activity
# 38           10962          117              2     11081
# 85             239         7007           1334      8580
# 32               0         4012            972      4984
# 73            2891          133              6      3030
# 64              50         1932            449      2431

# %%
posts.to_csv('most_popular_posts.csv')

# %% [markdown]
# ## EXTRA
#
# __К 50 самым популярным постам выгрузи все комментарии, чтобы оценить, как пользователи восприняли посты__
#
# 1. Создай цикл, который проходит по всем `post ID`
# 2. В каждом цикле собери все комментарии к посту, используя `offset`
# 3. В каждом цикле достань лайки в отдельный столбец
# 4. Собери все комментарии в одном датафрейме
#
#
#
# *Обрати внимание, что для работы с постами нужны __дополнительные параметры в токене__*

# %% [markdown]
# # 🎉🎉🎉 Поздравляем, ты великолепен!
